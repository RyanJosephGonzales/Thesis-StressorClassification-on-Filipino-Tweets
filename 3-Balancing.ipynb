# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("ldaTl.csv")
df
# Out:
#       score                                               text  \
# 0         1   uy  gagi  wag  kang  magpaniwala  haka  hakan...
# 1         2   marcos  duterte  pinag  parehong  tuta  dikta...
# 2         2   malinaw  malinaw  malinaw  pinapatagal  pande...
# 3         1   marcos  magiging  bayani  basahin  buong  pah...
# 4         2     neveragaintomartiallaw  resist  rehabilitat...
# ...     ...                                                ...
# 2349      1   bobong  marcos  cant  even  admit  fault  fam...
# 2350      1                 sofa  yung  presidency  stomoyern
# 2351      1     parang  di  presidency  pinaguusapan  pleek
# 2352      1      presidency  occupation  essence  terrorism
# 2353      1   mo  respetuhin  yung  choice  mo  iboboto  mo...
#
#                        Topics
# 0     Filipino Political News
# 1     Filipino Political News
# 2            Political stance
# 3     Filipino Political News
# 4            Political stance
# ...

# %%
top_0 = df.loc[df["Topics"] == "Government Policies"]
top_0 = top_0.head(280)
top_0
# Out:
#       score                                               text  \
# 10        1     put  anti  communism  nationalism  supporte...
# 18        1   skl  ganda  talk  kasi  makukuha  natin  firs...
# 21        1   remember  drug  war  grabe  real  problem  li...
# 61        2   oust  duterte  stop  killing  ligtas  balik  ...
# 74        2     png  nyo  pu  ina  nyong  dilawan  pag  gis...
# ...     ...                                                ...
# 2014      1   story  like  spread  malaman  sambayanan  kag...
# 2022      1   vp  hinted  possible  running  presidency  dd...
# 2032      1     agree  troll  wla  akong  binanggit  troll ...
# 2034      1   thanks  philippine  medium  non  stop  pr  jo...
# 2041      1     campaign  lacson  also  remember  cement  s...
#
#                    Topics
# 10    Government Policies
# 18    Government Policies
# 21    Government Policies
# 61    Government Policies
# 74    Government Policies
# ...                   ...
# ...

# %%
top_1 = df.loc[df["Topics"] == "Election"]
top_1 = top_1.head(280)
top_1
# Out:
#       score                                               text    Topics
# 13        1   remember  history  resist  historical  negati...  Election
# 38        1   filipino  word  trapo  translated  firstly  m...  Election
# 76        2     first  time  ba  prrd  sumali  high  level ...  Election
# 88        1   eme  essay  writing  toni  marcos  history  i...  Election
# 94        1   lord  want  family  healthy  strong  please  ...  Election
# ...     ...                                                ...       ...
# 2290      1     truth  always  come  matter  obstruction  d...  Election
# 2293      1               dutertes  presidential  candidate     Election
# 2329      1     maraming  salamat  po  kay  duterte  marcos...  Election
# 2333      1     supporter  duterte  immoral  action  made  ...  Election
# 2342      1     doh  need  append  vaccination  status  new...  Election
#
# [280 rows x 3 columns]

# %%
top_2 = df.loc[df["Topics"] == "Filipino Political News"]
top_2 = top_2.head(280)
top_2
# Out:
#      score                                               text  \
# 0        1   uy  gagi  wag  kang  magpaniwala  haka  hakan...
# 1        2   marcos  duterte  pinag  parehong  tuta  dikta...
# 3        1   marcos  magiging  bayani  basahin  buong  pah...
# 6        1     neveragain  notohistoricalrevisionism  endi...
# 7        2   duterte  marcos  pinag  parehong  tuta  dikta...
# ..     ...                                                ...
# 813      1     neveragain  dilawan  puro  pangbrabrain  wa...
# 818      1                               neveragain  dilawan
# 820      2     neveragain  dilawan  neverforget  katangaha...
# 821      2     neveragain  dilawan  neverforget  katangaha...
# 823      2     neveragain  dilawan  neverforget  katangaha...
#
#                       Topics
# 0    Filipino Political News
# 1    Filipino Political News
# 3    Filipino Political News
# 6    Filipino Political News
# 7    Filipino Political News
# ..                       ...
# ...

# %%
top_3 = df.loc[df["Topics"] == "Political stance"]
top_3 = top_3.head(280)
top_3
# Out:
#      score                                               text  \
# 2        2   malinaw  malinaw  malinaw  pinapatagal  pande...
# 4        2     neveragaintomartiallaw  resist  rehabilitat...
# 12       1   paulit  ulit  kayo  apologist  dilawan  dd  n...
# 20       2   never  martial  law  oust  duterte  read  ful...
# 24       1   ibang  bansa  nang  face  face  class  naman ...
# ..     ...                                                ...
# 731      1   amg  daming  pro  marcos  dilawan  ta  dd  fe...
# 732      1   okay  lang  pag  tinatawag  akong  dilawan  t...
# 733      1     lang  kinontra  boy  tikol  eh  noh  pag  d...
# 735      2                       ulol  tangina  nyo  dilawan
# 737      1   nganong  mo  comment  marcos  meme  ug  dd  m...
#
#                Topics
# 2    Political stance
# 4    Political stance
# 12   Political stance
# 20   Political stance
# 24   Political stance
# ..                ...
# 731  Political stance
# 732  Political stance
# ...

# %%
top_4 = df.loc[df["Topics"] == "President"]
top_4 = top_4.head(280)
top_4
# Out:
#       score                                               text     Topics
# 5         1   remember  49th  anniversary  martial  law  ca...  President
# 17        1   alzo  di  lang  magbibigay  historical  conte...  President
# 47        1   dala  galit  naunang  peryodistang  nagtaguyo...  President
# 51        1     dream  goal  without  anything  shall  deve...  President
# 183       1     katrinadomingo  remember  di  terorista  ma...  President
# ...     ...                                                ...        ...
# 2344      1   presidency  reporting  economy  strongly  hop...  President
# 2345      1   splice  video  leni  make  look  like  shes  ...  President
# 2347      1     politics  kpop  twt  honestly  naman  ibobo...  President
# 2348      1   oh  honey  eating  grumpy  llama  isnt  going...  President
# 2350      1                 sofa  yung  presidency  stomoyern   President
#
# [280 rows x 3 columns]

# %%
merge = [top_0, top_1, top_2, top_3, top_4]
top_all = pd.concat(merge)
top_all
# Out:
#       score                                               text  \
# 10        1     put  anti  communism  nationalism  supporte...
# 18        1   skl  ganda  talk  kasi  makukuha  natin  firs...
# 21        1   remember  drug  war  grabe  real  problem  li...
# 61        2   oust  duterte  stop  killing  ligtas  balik  ...
# 74        2     png  nyo  pu  ina  nyong  dilawan  pag  gis...
# ...     ...                                                ...
# 2344      1   presidency  reporting  economy  strongly  hop...
# 2345      1   splice  video  leni  make  look  like  shes  ...
# 2347      1     politics  kpop  twt  honestly  naman  ibobo...
# 2348      1   oh  honey  eating  grumpy  llama  isnt  going...
# 2350      1                 sofa  yung  presidency  stomoyern
#
#                    Topics
# 10    Government Policies
# 18    Government Policies
# 21    Government Policies
# 61    Government Policies
# 74    Government Policies
# ...                   ...
# ...

# %%
top_all.to_csv(r"ldaTlB.csv", index = False)

# %%
df1 = pd.read_csv("ldaEn.csv")
df1
# Out:
#       score                                               text  \
# 0         1   rip  pang  lakad  damit  lang  pang  bahay  o...
# 1         2   ever  since  rise  fall  dictator  ferdinand ...
# 2         2   ika  apatnaput  siyam  taon  nang  ipinataw  ...
# 3         1     neverforget  neveragain  oustduterte  impea...
# 4         2   uy  gagi  wag  mong  palampasin  araw  upang ...
# ...     ...                                                ...
# 3202      1     romeo  nasapol  mo  isko  galing  medyo  ta...
# 3203      1     dati  daw  yang  rebelde  noong  martial  l...
# 3204      1   help  slow  spread  covid19  identify  risk  ...
# 3205      1     emotionally  tough  see  patient  fighting ...
# 3206      1   vaccine  used  southafrica  tested  approved ...
#
#                        Topics
# 0                Recollection
# 1            Politican Stance
# 2                Recollection
# 3                Recollection
# 4                Recollection
# ...

# %%
top1_0 = df1.loc[df1['Topics'] == 'Government Policies']
top1_0 = top1_0.head(390)
top1_0
# Out:
#       score                                               text  \
# 33        1   paulit  ulit  kayo  apologist  dilawan  dd  n...
# 44        2   remember  drug  war  grabe  real  problem  li...
# 47        1   ibang  bansa  nang  face  face  class  naman ...
# 64        1   woohoo  naglalabasan  baho  wonder  anong  ba...
# 87        2   oust  duterte  stop  killing  ligtas  balik  ...
# ...     ...                                                ...
# 3146      1   tangina  niyo  pala  eh  hahaha  higanti  lan...
# 3156      1   good  duterte  roque  finally  got  around  c...
# 3161      1   ganito  kalakaran  pala  anong  point  deadli...
# 3171      1                       ye  doh  self  confidence
# 3172      1   de  doh  yaar  pls  kindly  consider  nationa...
#
#                    Topics
# 33    Government Policies
# 44    Government Policies
# 47    Government Policies
# 64    Government Policies
# 87    Government Policies
# ...                   ...
# ...

# %%
top1_1 = df1.loc[df1['Topics'] == "Filipino Political News"]
top1_1 = top1_1.head(390)
top1_1
# Out:
#       score                                               text  \
# 7         1   time  wait  2022  police  action  today  prot...
# 15        1   commemorate  today  stand  right  freedom  re...
# 17        1   move  martial  law  today  protester  hurt  h...
# 40        1   alzo  di  lang  magbibigay  historical  conte...
# 114       1   experience  kanina  napatanong  nalang  ba  e...
# ...     ...                                                ...
# 3094      1     rappler  vocal  duterte  administration  ma...
# 3100      1   itong  tuntungan  diba  ayaw  mo  kay  dutert...
# 3119      1     kanser  naman  kasi  lipunan  si  duterte  ...
# 3147      1     first  ever  nobel  peace  prize  took  3  ...
# 3160      1     actually  really  didnt  care  abt  withdra...
#
#                        Topics
# 7     Filipino Political News
# 15    Filipino Political News
# 17    Filipino Political News
# 40    Filipino Political News
# 114   Filipino Political News
# ...

# %%
top1_2 = df1.loc[df1['Topics'] == "Politican Stance"]
top1_2 = top1_2.head(390)
top1_2
# Out:
#       score                                               text  \
# 1         2   ever  since  rise  fall  dictator  ferdinand ...
# 6         2     ilang  oust  duterte  nga  kayo  eh  oust  ...
# 9         1                                     oust  duterte
# 19        1     state  controlled  funded  sambayanan  allo...
# 22        1   malinaw  malinaw  malinaw  pinapatagal  pande...
# ...     ...                                                ...
# 1907      1     busy  si  duterte  pagtanaw  utang  loob  t...
# 1908      2   group  also  criticized  duterte  administrat...
# 1909      2   main  architect  philippine  president  rodri...
# 1911      1                 pls  maybe  he  better  duterte
# 1912      1     neveragain  marcos  duterte  saw  fb  post ...
#
#                 Topics
# 1     Politican Stance
# 6     Politican Stance
# 9     Politican Stance
# 19    Politican Stance
# 22    Politican Stance
# ...                ...
# 1907  Politican Stance
# ...

# %%
top1_3 = df1.loc[df1['Topics'] == "Election"]
top1_3 = top1_3.head(390)
top1_3
# Out:
#       score                                               text    Topics
# 5         1   akala  burger  king  snr  pala  hehehe  okay ...  Election
# 8         1                                           tangina   Election
# 12        1   nagkakaisa  malawak  hanay  sambayanan  oustd...  Election
# 51        2      tanginanyo  asan  yung  oustduterte  natin     Election
# 52        1   ma  mukha  pang  presidente  kesa  presidente...  Election
# ...     ...                                                ...       ...
# 1114      1                           dilawan  tang  ina  nyo   Election
# 1116      2                               kelan  di  binoto     Election
# 1118      2     kasinungalingan  dilawan  masahol  asong  p...  Election
# 1119      1     sinong  political  analyst  yan  yung  dila...  Election
# 1121      2     marcos  best  president  dilawan  mangmang ...  Election
#
# [390 rows x 3 columns]

# %%
top1_4 = df1.loc[df1['Topics'] == "Recollection"]
top1_4 = top1_4.head(390)
top1_4
# Out:
#       score                                               text        Topics
# 0         1   rip  pang  lakad  damit  lang  pang  bahay  o...  Recollection
# 2         2   ika  apatnaput  siyam  taon  nang  ipinataw  ...  Recollection
# 3         1     neverforget  neveragain  oustduterte  impea...  Recollection
# 4         2   uy  gagi  wag  mong  palampasin  araw  upang ...  Recollection
# 10        1   labanan  biguin  tiraniya  malawakang  korups...  Recollection
# ...     ...                                                ...           ...
# 1436      2   pinagkaiba  duterte  marcos  neveragain  neve...  Recollection
# 1437      1   marcos  duterte  pinagkaiba  panagutin  dikta...  Recollection
# 1451      2   kababaihan  labangabriela  magatal  kayong  n...  Recollection
# 1453      1   duterte  hold  beer  neveragain  neverforget ...  Recollection
# 1459      2   icymi  ngayong  komemorasyon  martial  law  n...  Recollection
#
# [390 rows x 3 columns]

# %%
merge1 = [top1_0, top1_1, top1_2, top1_3, top1_4]
top1_all = pd.concat(merge1)
top1_all
# Out:
#       score                                               text  \
# 33        1   paulit  ulit  kayo  apologist  dilawan  dd  n...
# 44        2   remember  drug  war  grabe  real  problem  li...
# 47        1   ibang  bansa  nang  face  face  class  naman ...
# 64        1   woohoo  naglalabasan  baho  wonder  anong  ba...
# 87        2   oust  duterte  stop  killing  ligtas  balik  ...
# ...     ...                                                ...
# 1436      2   pinagkaiba  duterte  marcos  neveragain  neve...
# 1437      1   marcos  duterte  pinagkaiba  panagutin  dikta...
# 1451      2   kababaihan  labangabriela  magatal  kayong  n...
# 1453      1   duterte  hold  beer  neveragain  neverforget ...
# 1459      2   icymi  ngayong  komemorasyon  martial  law  n...
#
#                    Topics
# 33    Government Policies
# 44    Government Policies
# 47    Government Policies
# 64    Government Policies
# 87    Government Policies
# ...                   ...
# ...

# %%
top1_all.to_csv(r"ldaEnB.csv", index = False)
