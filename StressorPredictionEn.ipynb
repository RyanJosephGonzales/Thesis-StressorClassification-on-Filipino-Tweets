# %% [markdown]
# # I.Import Necessary Dependencies and Settings¶

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import re
import nltk
import spacy
import gensim
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from gensim import corpora, models
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.model_selection import GridSearchCV
pd.options.display.max_colwidth = 200
# %matplotlib inline

# %% [markdown]
# # II.Dataset Import

# %%
df = pd.read_csv('UnlistedEnglish1.csv', error_bad_lines=False)
df.head()
# Out:
#    score  \
# 0      1
# 1      2
# 2      2
# 3      1
# 4      2
#
#                                                                                                                                                                                                       text
# 0                                                                                                                                                 rip  pang  lakad  damit  lang  pang  bahay  oustduterte
# 1   ever  since  rise  fall  dictator  ferdinand  marcos  student  youth  forefront  tyranny  fascism  corruption  john  robert  de  castro  amp  natalie  nicole  julian  aster  lopez  read  neverfor...
# 2   ika  apatnaput  siyam  taon  nang  ipinataw  bata  militar  nakikiisa  panday  sining  bacoor  handog  tula  alalahanin  nangahas  biktima  malagim  unos  diktadurang  marcos  neverforget  marcos...
# 3                                                                                                                                                    neverforget  neveragain  oustduterte  impeachduterte
# 4                                                          uy  gagi  wag  mong  palampasin  araw  upang  aralin  rise  fall  marcos  dictatorship  dalo  kayo  ed  neveragain  neverforget  oustduterte

# %% [markdown]
# # III.Data Cleaning

# %%
# Convert to list
data = df.text.values.tolist()
# Remove Emails
data = [re.sub(r'\S*@\S*\s?', '', sent) for sent in data]
# Remove new line characters
data = [re.sub(r'\s+', ' ', sent) for sent in data]
# Remove distracting single quotes
data = [re.sub(r"\'", "", sent) for sent in data]
print(data[:1])
# Out:
# [' rip pang lakad damit lang pang bahay oustduterte ']

# %% [markdown]
# ### Tokenize

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations
data_words = list(sent_to_words(data))
print(data_words[:1])
# Out:
# [['rip', 'pang', 'lakad', 'damit', 'lang', 'pang', 'bahay', 'oustduterte']]

# %% [markdown]
# ### Stemming

# %%
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']): #'NOUN', 'ADJ', 'VERB', 'ADV'
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append(" ".join([token.lemma_ if token.lemma_ not in ['-PRON-'] else '' for token in doc if token.pos_ in allowed_postags]))
    return texts_out

# %%
nlp = spacy.load("en_core_web_sm")
# Do lemmatization keeping only Noun, Adj, Verb, Adverb
data_lemmatized = lemmatization(data_words, allowed_postags=['NOUN', 'VERB']) #select noun and verb
print(data_lemmatized[:2])
# Out:
# ['oustduterte', 'rise fall dictator student youth forefront corruption read neverforget oustduterte']

# %% [markdown]
# # IV.Create the Document-Word matrix

# %%
vectorizer = CountVectorizer(analyzer='word',       
                             min_df=10,
# minimum reqd occurences of a word 
                             stop_words='english',             
# remove stop words
                             lowercase=True,                   
# convert all words to lowercase
                             token_pattern='[a-zA-Z0-9]{3,}',  
# num chars > 3
                             max_features=50000)           
# max number of uniq words    
data_vectorized = vectorizer.fit_transform(data_lemmatized)

# %% [markdown]
# # V.Build LDA model with sklearn

# %%
# Build LDA Model
lda_model = LatentDirichletAllocation(n_components=5,               # Number of topics
                                      max_iter=10,               
# Max learning iterations
                                      learning_method='online',   
                                      random_state=100,          
# Random state
                                      batch_size=128,            
# n docs in each learning iter
                                      evaluate_every = -1,       
# compute perplexity every n iters, default: Don't
                                      n_jobs = -1,               
# Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_vectorized)
print(lda_model)  # Model attributes
# Out:
# LatentDirichletAllocation(learning_method='online', n_components=5, n_jobs=-1,
#                           random_state=100)

# %%
LatentDirichletAllocation(batch_size=128, doc_topic_prior=None, evaluate_every=-1, learning_decay=0.7,
                          learning_method='online', learning_offset=10.0, max_doc_update_iter=100, 
                          max_iter=10, mean_change_tol=0.001, n_components=5, n_jobs=-1, 
                          perp_tol=0.1,random_state=100, topic_word_prior=None, total_samples=1000000.0, verbose=0)
# Out:
# LatentDirichletAllocation(learning_method='online', n_components=5, n_jobs=-1,
#                           random_state=100)

# %% [markdown]
# # VI.Diagnose model performance with perplexity and log-likelihood

# %%
# Log Likelyhood: Higher the better
print("Log Likelihood: ", lda_model.score(data_vectorized))
# Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
print("Perplexity: ", lda_model.perplexity(data_vectorized))
# See model parameters
print(lda_model.get_params())
# Out:
# Log Likelihood:  -38029.58362581908
# Perplexity:  196.30837118342106
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'online', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 5, 'n_jobs': -1, 'perp_tol': 0.1, 'random_state': 100, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}

# %%
# Define Search Param
search_params = {'n_components': [5, 6, 7, 8, 9], 'learning_decay': [.5, .7, .9]}
# Init the Model
lda = LatentDirichletAllocation(max_iter=5, learning_method='online', learning_offset=50.,random_state=0)
# Init Grid Search Class
model = GridSearchCV(lda, param_grid=search_params)
# Do the Grid Search
model.fit(data_vectorized)
# Out:
# GridSearchCV(estimator=LatentDirichletAllocation(learning_method='online',
#                                                  learning_offset=50.0,
#                                                  max_iter=5, random_state=0),
#              param_grid={'learning_decay': [0.5, 0.7, 0.9],
#                          'n_components': [5, 6, 7, 8, 9]})

# %%
# Best Model
best_lda_model = model.best_estimator_
# Model Parameters
print("Best Model's Params: ", model.best_params_)
# Log Likelihood Score
print("Best Log Likelihood Score: ", model.best_score_)
# Perplexity
print("Model Perplexity: ", best_lda_model.perplexity(data_vectorized))
# Out:
# Best Model's Params:  {'learning_decay': 0.5, 'n_components': 5}
# Best Log Likelihood Score:  -9695.10994052303
# Model Perplexity:  209.5061597009758

# %% [markdown]
# # VII.Dominant topic

# %%
# Create Document — Topic Matrix
lda_output = best_lda_model.transform(data_vectorized)
# column names
topicnames = ["Topic" + str(i) for i in range(best_lda_model.n_components)]
# index names
docnames = ["Doc" + str(i) for i in range(len(data))]
# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns=topicnames, index=docnames)
# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic
# Styling
def color_green(val):
 color = 'green' if val > .1 else 'black'
 return 'color: {col}'.format(col=color)
def make_bold(val):
 weight = 700 if val > .1 else 400
 return 'font-weight: {weight}'.format(weight=weight)
# Apply Style
df_document_topics = df_document_topic.head(15).style.applymap(color_green).applymap(make_bold)
df_document_topics
# Out:
# <style type="text/css">
# #T_ea0ca_row0_col0, #T_ea0ca_row0_col1, #T_ea0ca_row0_col3, #T_ea0ca_row0_col4, #T_ea0ca_row1_col0, #T_ea0ca_row1_col1, #T_ea0ca_row1_col3, #T_ea0ca_row2_col0, #T_ea0ca_row2_col1, #T_ea0ca_row2_col3, #T_ea0ca_row2_col4, #T_ea0ca_row3_col0, #T_ea0ca_row3_col1, #T_ea0ca_row3_col3, #T_ea0ca_row3_col4, #T_ea0ca_row4_col0, #T_ea0ca_row4_col1, #T_ea0ca_row4_col3, #T_ea0ca_row4_col4, #T_ea0ca_row5_col5, #T_ea0ca_row6_col0, #T_ea0ca_row6_col1, #T_ea0ca_row6_col2, #T_ea0ca_row6_col3, #T_ea0ca_row7_col0, #T_ea0ca_row7_col1, #T_ea0ca_row7_col4, #T_ea0ca_row8_col5, #T_ea0ca_row9_col0, #T_ea0ca_row9_col1, #T_ea0ca_row9_col2, #T_ea0ca_row9_col3, #T_ea0ca_row10_col0, #T_ea0ca_row10_col1, #T_ea0ca_row10_col3, #T_ea0ca_row10_col4, #T_ea0ca_row11_col0, #T_ea0ca_row11_col1, #T_ea0ca_row11_col3, #T_ea0ca_row11_col4, #T_ea0ca_row12_col5, #T_ea0ca_row13_col0, #T_ea0ca_row13_col1, #T_ea0ca_row13_col3, #T_ea0ca_row13_col4, #T_ea0ca_row14_col0, #T_ea0ca_row14_col1, #T_ea0ca_row14_col3, #T_ea0ca_row14_col4 {
#   color: black;
#   font-weight: 400;
# }
# #T_ea0ca_row0_col2, #T_ea0ca_row0_col5, #T_ea0ca_row1_col2, #T_ea0ca_row1_col4, #T_ea0ca_row1_col5, #T_ea0ca_row2_col2, #T_ea0ca_row2_col5, #T_ea0ca_row3_col2, #T_ea0ca_row3_col5, #T_ea0ca_row4_col2, #T_ea0ca_row4_col5, #T_ea0ca_row5_col0, #T_ea0ca_row5_col1, #T_ea0ca_row5_col2, #T_ea0ca_row5_col3, #T_ea0ca_row5_col4, #T_ea0ca_row6_col4, #T_ea0ca_row6_col5, #T_ea0ca_row7_col2, #T_ea0ca_row7_col3, #T_ea0ca_row7_col5, #T_ea0ca_row8_col0, #T_ea0ca_row8_col1, #T_ea0ca_row8_col2, #T_ea0ca_row8_col3, #T_ea0ca_row8_col4, #T_ea0ca_row9_col4, #T_ea0ca_row9_col5, #T_ea0ca_row10_col2, #T_ea0ca_row10_col5, #T_ea0ca_row11_col2, #T_ea0ca_row11_col5, #T_ea0ca_row12_col0, #T_ea0ca_row12_col1, #T_ea0ca_row12_col2, #T_ea0ca_row12_col3, #T_ea0ca_row12_col4, #T_ea0ca_row13_col2, #T_ea0ca_row13_col5, #T_ea0ca_row14_col2, #T_ea0ca_row14_col5 {
#   color: green;
#   font-weight: 700;
# }
# </style>
# <table id="T_ea0ca_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Topic0</th>
#       <th class="col_heading level0 col1" >Topic1</th>
#       <th class="col_heading level0 col2" >Topic2</th>
#       <th class="col_heading level0 col3" >Topic3</th>
#       <th class="col_heading level0 col4" >Topic4</th>
#       <th class="col_heading level0 col5" >dominant_topic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea0ca_level0_row0" class="row_heading level0 row0" >Doc0</th>
#       <td id="T_ea0ca_row0_col0" class="data row0 col0" >0.100000</td>
#       <td id="T_ea0ca_row0_col1" class="data row0 col1" >0.100000</td>
#       <td id="T_ea0ca_row0_col2" class="data row0 col2" >0.600000</td>
#       <td id="T_ea0ca_row0_col3" class="data row0 col3" >0.100000</td>
#       <td id="T_ea0ca_row0_col4" class="data row0 col4" >0.100000</td>
#       <td id="T_ea0ca_row0_col5" class="data row0 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ea0ca_level0_row1" class="row_heading level0 row1" >Doc1</th>
#       <td id="T_ea0ca_row1_col0" class="data row1 col0" >0.030000</td>
#       <td id="T_ea0ca_row1_col1" class="data row1 col1" >0.030000</td>
#       <td id="T_ea0ca_row1_col2" class="data row1 col2" >0.430000</td>
#       <td id="T_ea0ca_row1_col3" class="data row1 col3" >0.030000</td>
#       <td id="T_ea0ca_row1_col4" class="data row1 col4" >0.480000</td>
#       <td id="T_ea0ca_row1_col5" class="data row1 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ea0ca_level0_row2" class="row_heading level0 row2" >Doc2</th>
#       <td id="T_ea0ca_row2_col0" class="data row2 col0" >0.100000</td>
#       <td id="T_ea0ca_row2_col1" class="data row2 col1" >0.100000</td>
#       <td id="T_ea0ca_row2_col2" class="data row2 col2" >0.600000</td>
#       <td id="T_ea0ca_row2_col3" class="data row2 col3" >0.100000</td>
#       <td id="T_ea0ca_row2_col4" class="data row2 col4" >0.100000</td>
#       <td id="T_ea0ca_row2_col5" class="data row2 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ea0ca_level0_row3" class="row_heading level0 row3" >Doc3</th>
#       <td id="T_ea0ca_row3_col0" class="data row3 col0" >0.070000</td>
#       <td id="T_ea0ca_row3_col1" class="data row3 col1" >0.070000</td>
#       <td id="T_ea0ca_row3_col2" class="data row3 col2" >0.730000</td>
#       <td id="T_ea0ca_row3_col3" class="data row3 col3" >0.070000</td>
#       <td id="T_ea0ca_row3_col4" class="data row3 col4" >0.070000</td>
#       <td id="T_ea0ca_row3_col5" class="data row3 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ea0ca_level0_row4" class="row_heading level0 row4" >Doc4</th>
#       <td id="T_ea0ca_row4_col0" class="data row4 col0" >0.040000</td>
#       <td id="T_ea0ca_row4_col1" class="data row4 col1" >0.040000</td>
#       <td id="T_ea0ca_row4_col2" class="data row4 col2" >0.840000</td>
#       <td id="T_ea0ca_row4_col3" class="data row4 col3" >0.040000</td>
#       <td id="T_ea0ca_row4_col4" class="data row4 col4" >0.040000</td>
#       <td id="T_ea0ca_row4_col5" class="data row4 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ea0ca_level0_row5" class="row_heading level0 row5" >Doc5</th>
#       <td id="T_ea0ca_row5_col0" class="data row5 col0" >0.200000</td>
#       <td id="T_ea0ca_row5_col1" class="data row5 col1" >0.200000</td>
#       <td id="T_ea0ca_row5_col2" class="data row5 col2" >0.200000</td>
#       <td id="T_ea0ca_row5_col3" class="data row5 col3" >0.200000</td>
#       <td id="T_ea0ca_row5_col4" class="data row5 col4" >0.200000</td>
#       <td id="T_ea0ca_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ea0ca_level0_row6" class="row_heading level0 row6" >Doc6</th>
#       <td id="T_ea0ca_row6_col0" class="data row6 col0" >0.070000</td>
#       <td id="T_ea0ca_row6_col1" class="data row6 col1" >0.070000</td>
#       <td id="T_ea0ca_row6_col2" class="data row6 col2" >0.070000</td>
#       <td id="T_ea0ca_row6_col3" class="data row6 col3" >0.070000</td>
#       <td id="T_ea0ca_row6_col4" class="data row6 col4" >0.730000</td>
#       <td id="T_ea0ca_row6_col5" class="data row6 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ea0ca_level0_row7" class="row_heading level0 row7" >Doc7</th>
#       <td id="T_ea0ca_row7_col0" class="data row7 col0" >0.030000</td>
#       <td id="T_ea0ca_row7_col1" class="data row7 col1" >0.030000</td>
#       <td id="T_ea0ca_row7_col2" class="data row7 col2" >0.150000</td>
#       <td id="T_ea0ca_row7_col3" class="data row7 col3" >0.770000</td>
#       <td id="T_ea0ca_row7_col4" class="data row7 col4" >0.030000</td>
#       <td id="T_ea0ca_row7_col5" class="data row7 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ea0ca_level0_row8" class="row_heading level0 row8" >Doc8</th>
#       <td id="T_ea0ca_row8_col0" class="data row8 col0" >0.200000</td>
#       <td id="T_ea0ca_row8_col1" class="data row8 col1" >0.200000</td>
#       <td id="T_ea0ca_row8_col2" class="data row8 col2" >0.200000</td>
#       <td id="T_ea0ca_row8_col3" class="data row8 col3" >0.200000</td>
#       <td id="T_ea0ca_row8_col4" class="data row8 col4" >0.200000</td>
#       <td id="T_ea0ca_row8_col5" class="data row8 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ea0ca_level0_row9" class="row_heading level0 row9" >Doc9</th>
#       <td id="T_ea0ca_row9_col0" class="data row9 col0" >0.070000</td>
#       <td id="T_ea0ca_row9_col1" class="data row9 col1" >0.070000</td>
#       <td id="T_ea0ca_row9_col2" class="data row9 col2" >0.070000</td>
#       <td id="T_ea0ca_row9_col3" class="data row9 col3" >0.070000</td>
#       <td id="T_ea0ca_row9_col4" class="data row9 col4" >0.730000</td>
#       <td id="T_ea0ca_row9_col5" class="data row9 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_ea0ca_level0_row10" class="row_heading level0 row10" >Doc10</th>
#       <td id="T_ea0ca_row10_col0" class="data row10 col0" >0.070000</td>
#       <td id="T_ea0ca_row10_col1" class="data row10 col1" >0.070000</td>
#       <td id="T_ea0ca_row10_col2" class="data row10 col2" >0.730000</td>
#       <td id="T_ea0ca_row10_col3" class="data row10 col3" >0.070000</td>
#       <td id="T_ea0ca_row10_col4" class="data row10 col4" >0.07

# %%
# Topic-Keyword Matrix
df_topic_keywords = pd.DataFrame(best_lda_model.components_)
# Assign Column and Index
df_topic_keywords.columns = vectorizer.get_feature_names()
df_topic_keywords.index = topicnames
# View
df_topic_keywords.head()
# Out:
#           action       add   address      admin  administration      agree  \
# Topic0  0.202724  8.429892  0.202612   0.200575        0.202280  11.437084
# Topic1  0.204075  0.204099  9.896207   0.200922       23.195049   0.202278
# Topic2  0.201967  0.200448  0.200019   0.201499        0.201001   0.200326
# Topic3  8.665648  0.200877  0.201132   0.202665        0.203976   0.201159
# Topic4  0.201495  0.200655  0.202016  13.342689        0.204564   0.203306
#
#            allege      allow        amp  anibersaryo  ...      wake  \
# Topic0  12.736883   0.205194   0.203374     0.200283  ...  0.200769
# Topic1   0.205569  11.998768   0.201364     0.200474  ...  0.202420
# Topic2   0.202138   0.201986   0.659488    16.503093  ...  0.200257
# Topic3   0.201747   0.200286  83.077549     0.201837  ...  8.808743
# Topic4   0.203828   0.204975   0.205942     0.200724  ...  0.201529
#
#              want        war      watch        way        win       work  \
# Topic0  31.792587   0.203731   0.203978   0.204528   0.202887   0.202218
# Topic1   0.203185  28.223478   0.202980   0.204837  22.508604   0.201835
# Topic2   0.202738   0.200835   0.201285   0.200702   0.201058   0.201679
# Topic3   0.204539   0.203720  18.072496  24.961097   0.202665   0.203218
# Topic4  15.497833   0.202983   0.202288   0.203604   0.202892  28.741750
#
#            worker      world       year
# Topic0   0.203243   0.203283   0.202740
# Topic1   0.201251   0.204475  40.147667
# Topic2  11.422106   0.201326   0.202600
# Topic3   0.202525   0.201770  12.175404
# Topic4   0.201344  10.450500   0.202735
#
# [5 rows x 251 columns]

# %% [markdown]
# ### Get the top 15 keywords each topic:

# %%
# Show top n keywords for each topic
def show_topics(vectorizer=vectorizer, lda_model=lda_model, n_words=100):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords
topic_keywords = show_topics(vectorizer=vectorizer, lda_model=best_lda_model, n_words=100)
# Topic - Keywords Dataframe
df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Topic '+str(i) for i in range(df_topic_keywords.shape[0])]
pd.set_option('display.max_columns', None)
df_topic_keywords.head()
# Out:
#              Word 0       Word 1     Word 2       Word 3 Word 4 Word 5  \
# Topic 0     respect         vote    country      dilawan    use   test
# Topic 1  presidency         kayo   election         face   hope   case
# Topic 2  neveragain  oustduterte  president  neverforget   gale  story
# Topic 3         law         time     choice       people    amp    bbm
# Topic 4     duterte          say  candidate      support   need    try
#
#              Word 6   Word 7          Word 8      Word 9     Word 10  \
# Topic 0         run   health            help        feel       covid
# Topic 1        file  problem            make        drug        year
# Topic 2  government      daw  oustdutertenow  journalist     history
# Topic 3      talaga     life          report     include         day
# Topic 4       think     muna            oust  opposition  philippine
#
#            Word 11   Word 12         Word 13  Word 14      Word 15  \
# Topic 0     follow      leni             ask     know       leader
# Topic 1       come       war          shield      doh        class
# Topic 2      mayor    regime  dutertewakasan   budget  anibersaryo
# Topic 3     happen  pilipina          aquino  marcose         tell
# Topic 4  supporter     thank      corruption     work          run
#
#                 Word 16 Word 17 Word 18     Word 19  Word 20 Word 21  \
# Topic 0             say   court    want         let     read    make
# Topic 1  administration     pre     win      policy  halalan     sya
# Topic 2           bayan    pala   peace  magnanakaw     hear     lie
# Topic 3            look     way   power       start     talk    wait
# Topic 4        official    slap     end       bansa    naman     lol
#
#                  Word 22   Word 23 Word 24 Word 25     Word 26     Word 27  \
# Topic 0  bbmforpresident    people    lead    care    register  presidente
# Topic 1             kill  position     wag   build      result       bring
# Topic 2             vice      bata  worker   order  diktadurya        sign
# Topic 3            truth      dami  family     pre        view       watch
# Topic 4             stop      fact   group    puro        read     enabler
#
#             Word 28   Word 29    Word 30  Word 31  Word 32        Word 33  \
# Topic 0    continue     probe       vice   mother     news           love
# Topic 1  reconsider    change  apologist    leave     date  investigation
# Topic 2      number       let   remember     meet  patuloy        student
# Topic 3        mind   believe      issue    speak     pina           niyo
# Topic 4        post  campaign     hahaha  testing     want           mean
#
#            Word 34       Word 35    Word 36   Word 37   Word 38 Word 39  \
# Topic 0   eleksyon        friend      voter  question   opinion  allege
# Topic 1     nation        defend      pwede      plan    choose  tandem
# Topic 2  statement  dictatorship      level    supply       amp   fight
# Topic 3  interview       deserve  candidacy      year  response  decide
# Topic 4       fund        forget   dictator    debate    record   admin
#
#          Word 40 Word 41   Word 42   Word 43      Word 44   Word 45 Word 46  \
# Topic 0  protect   agree  filipino      hate        cross       kit  magige
# Topic 1      man   month    return      kaso        point  pilipino   allow
# Topic 2  marcose    muna     truth    debate      support      slap    link
# Topic 3    stand   fight      list    person  development   protest  police
# Topic 4  imagine   davao  hahahaha  decision       office     thing  attack
#
#              Word 47       Word 48 Word 49 Word 50    Word 51  Word 52  \
# Topic 0  anniversary         proof  member  victim      place      add
# Topic 1      address        nating     icc   learn        pag    crime
# Topic 2     official           try    life    mind        law      run
# Topic 3         lose         hirap    link   thing       kame     wake
# Topic 4       malake  dictatorship   elcac   world  statement  politic
#
#            Word 53      Word 54   Word 55        Word 56        Word 57  \
# Topic 0     supply  duqueresign    decide  duterterapist  dutertemanyak
# Topic 1  narrative         hour  campaign       filipino        duterte
# Topic 2    freedom  anniversary  campaign    duqueresign         talaga
# Topic 3       know       action     state            guy           join
# Topic 4    twitter        level  remember            lng          today
#
#             Word 58  Word 59  Word 60  Word 61      Word 62  Word 63  \
# Topic 0  philippine  problem    issue  include  oustduterte   report
# Topic 1      office   decide   report   victim      include      run
# Topic 2        fund    bansa     niyo  protect       change      pag
# Topic 3       today     toni  freedom   number         muna  dilawan
# Topic 4       state  patuloy    crime    month      freedom  student
#
#           Word 64     Word 65     Word 66   Word 67  Word 68    Word 69  \
# Topic 0   support        case      choice       law  duterte      month
# Topic 1  decision  philippine      choice       ask     vice  candidate
# Topic 2      join      decide    dictator      love   record      elcac
# Topic 3     story  presidency        gale  remember      try    respect
# Topic 4     fight        vote  journalist   opinion      let     choice
#
#             Word 70     Word 71    Word 72          Word 73   Word 74  \
# Topic 0  presidency   candidate      crime       reconsider   testing
# Topic 1       mayor       covid    testing            court      mind
# Topic 2        read       proof     nating         pilipino       say
# Topic 3       leave     problem  candidate  bbmforpresident  filipino
# Topic 4       story  presidency    respect            speak    family
#
#              Word 75 Word 76 Word 77      Word 78 Word 79  Word 80   Word 81  \
# Topic 0      halalan     bbm   order         need  nation   malake    choose
# Topic 1  oustduterte  allege    read       mother   state  respect  continue
# Topic 2         view  malake  victim         want  office   member      year
# Topic 3       victim  return    case        think     lol   choose      hope
# Topic 4       return    mind    life  oustduterte   court     gale     probe
#
#          Word 82  Word 83      Word 84    Word 85   Word 86 Word 87 Word 88  \
# Topic 0     plan     look    president    freedom    record    fund   allow
# Topic 1      say  freedom       record      probe      test   proof     way
# Topic 2      day     hope     response      today   deserve    come    time
# Topic 3  support   record  anniversary   dictator  campaign     say    hear
# Topic 4      amp    mayor       budget  president  continue  number   allow
#
#          Word 89 Word 90  Word 91     Word 92         Word 93  Word 94  \
# Topic 0   result  family  history       start            drug      way
# Topic 1   follow   world     time        help           order  protect
# Topic 2     look  choose     mean  corruption          health     kill
# Topic 3  opinion  malake    peace      hahaha           court   member
# Topic 4      pre    list     know   candidacy  administration     vice
#
#         Word 95     Word 96 Word 97       Word 98     Word 99
# Topic 0   think  opposition    hour      position      office
# Topic 1   think         add  action  dictatorship      happen
# Topic 2  allege       state    pina     interview       allow
# Topic 3    come        feel    want        budget  philippine
# Topic 4    drug        case  change        allege      people

# %% [markdown]
# ### Next, put the 5 topics we infered into the dataframe.

# %%
Topics = ["Election","Government Policies", "Recollection", "Filipino Political News","Politican Stance"]
df_topic_keywords["Topics"]=Topics
df_topic_keywords
# Out:
#              Word 0       Word 1     Word 2       Word 3 Word 4 Word 5  \
# Topic 0     respect         vote    country      dilawan    use   test
# Topic 1  presidency         kayo   election         face   hope   case
# Topic 2  neveragain  oustduterte  president  neverforget   gale  story
# Topic 3         law         time     choice       people    amp    bbm
# Topic 4     duterte          say  candidate      support   need    try
#
#              Word 6   Word 7          Word 8      Word 9     Word 10  \
# Topic 0         run   health            help        feel       covid
# Topic 1        file  problem            make        drug        year
# Topic 2  government      daw  oustdutertenow  journalist     history
# Topic 3      talaga     life          report     include         day
# Topic 4       think     muna            oust  opposition  philippine
#
#            Word 11   Word 12         Word 13  Word 14      Word 15  \
# Topic 0     follow      leni             ask     know       leader
# Topic 1       come       war          shield      doh        class
# Topic 2      mayor    regime  dutertewakasan   budget  anibersaryo
# Topic 3     happen  pilipina          aquino  marcose         tell
# Topic 4  supporter     thank      corruption     work          run
#
#                 Word 16 Word 17 Word 18     Word 19  Word 20 Word 21  \
# Topic 0             say   court    want         let     read    make
# Topic 1  administration     pre     win      policy  halalan     sya
# Topic 2           bayan    pala   peace  magnanakaw     hear     lie
# Topic 3            look     way   power       start     talk    wait
# Topic 4        official    slap     end       bansa    naman     lol
#
#                  Word 22   Word 23 Word 24 Word 25     Word 26     Word 27  \
# Topic 0  bbmforpresident    people    lead    care    register  presidente
# Topic 1             kill  position     wag   build      result       bring
# Topic 2             vice      bata  worker   order  diktadurya        sign
# Topic 3            truth      dami  family     pre        view       watch
# Topic 4             stop      fact   group    puro        read     enabler
#
#             Word 28   Word 29    Word 30  Word 31  Word 32        Word 33  \
# Topic 0    continue     probe       vice   mother     news           love
# Topic 1  reconsider    change  apologist    leave     date  investigation
# Topic 2      number       let   remember     meet  patuloy        student
# Topic 3        mind   believe      issue    speak     pina           niyo
# Topic 4        post  campaign     hahaha  testing     want           mean
#
#            Word 34       Word 35    Word 36   Word 37   Word 38 Word 39  \
# Topic 0   eleksyon        friend      voter  question   opinion  allege
# Topic 1     nation        defend      pwede      plan    choose  tandem
# Topic 2  statement  dictatorship      level    supply       amp   fight
# Topic 3  interview       deserve  candidacy      year  response  decide
# Topic 4       fund        forget   dictator    debate    record   admin
#
#          Word 40 Word 41   Word 42   Word 43      Word 44   Word 45 Word 46  \
# Topic 0  protect   agree  filipino      hate        cross       kit  magige
# Topic 1      man   month    return      kaso        point  pilipino   allow
# Topic 2  marcose    muna     truth    debate      support      slap    link
# Topic 3    stand   fight      list    person  development   protest  police
# Topic 4  imagine   davao  hahahaha  decision       office     thing  attack
#
#              Word 47       Word 48 Word 49 Word 50    Word 51  Word 52  \
# Topic 0  anniversary         proof  member  victim      place      add
# Topic 1      address        nating     icc   learn        pag    crime
# Topic 2     official           try    life    mind        law      run
# Topic 3         lose         hirap    link   thing       kame     wake
# Topic 4       malake  dictatorship   elcac   world  statement  politic
#
#            Word 53      Word 54   Word 55        Word 56        Word 57  \
# Topic 0     supply  duqueresign    decide  duterterapist  dutertemanyak
# Topic 1  narrative         hour  campaign       filipino        duterte
# Topic 2    freedom  anniversary  campaign    duqueresign         talaga
# Topic 3       know       action     state            guy           join
# Topic 4    twitter        level  remember            lng          today
#
#             Word 58  Word 59  Word 60  Word 61      Word 62  Word 63  \
# Topic 0  philippine  problem    issue  include  oustduterte   report
# Topic 1      office   decide   report   victim      include      run
# Topic 2        fund    bansa     niyo  protect       change      pag
# Topic 3       today     toni  freedom   number         muna  dilawan
# Topic 4       state  patuloy    crime    month      freedom  student
#
#           Word 64     Word 65     Word 66   Word 67  Word 68    Word 69  \
# Topic 0   support        case      choice       law  duterte      month
# Topic 1  decision  philippine      choice       ask     vice  candidate
# Topic 2      join      decide    dictator      love   record      elcac
# Topic 3     story  presidency        gale  remember      try    respect
# Topic 4     fight        vote  journalist   opinion      let     choice
#
#             Word 70     Word 71    Word 72          Word 73   Word 74  \
# Topic 0  presidency   candidate      crime       reconsider   testing
# Topic 1       mayor       covid    testing            court      mind
# Topic 2        read       proof     nating         pilipino       say
# Topic 3       leave     problem  candidate  bbmforpresident  filipino
# Topic 4       story  presidency    respect            speak    family
#
#              Word 75 Word 76 Word 77      Word 78 Word 79  Word 80   Word 81  \
# Topic 0      halalan     bbm   order         need  nation   malake    choose
# Topic 1  oustduterte  allege    read       mother   state  respect  continue
# Topic 2         view  malake  victim         want  office   member      year
# Topic 3       victim  return    case        think     lol   choose      hope
# Topic 4       return    mind    life  oustduterte   court     gale     probe
#
#          Word 82  Word 83      Word 84    Word 85   Word 86 Word 87 Word 88  \
# Topic 0     plan     look    president    freedom    record    fund   allow
# Topic 1      say  freedom       record      probe      test   proof     way
# Topic 2      day     hope     response      today   deserve    come    time
# Topic 3  support   record  anniversary   dictator  campaign     say    hear
# Topic 4      amp    mayor       budget  president  continue  number   allow
#
#          Word 89 Word 90  Word 91     Word 92         Word 93  Word 94  \
# Topic 0   result  family  history       start            drug      way
# Topic 1   follow   world     time        help           order  protect
# Topic 2     look  choose     mean  corruption          health     kill
# Topic 3  opinion  malake    peace      hahaha           court   member
# Topic 4      pre    list     know   candidacy  administration     vice
#
#         Word 95     Word 96 Word 97       Word 98     Word 99  \
# Topic 0   think  opposition    hour      position      office
# Topic 1   think         add  action  dictatorship      happen
# Topic 2  allege       state    pina     interview       allow
# Topic 3    come        feel    want        budget  philippine
# Topic 4    drug        case  change        allege      people
#
#                           Topics
# Topic 0                 Election
# Topic 1      Government Policies
# Topic 2             Recollection
# Topic 3  Filipino Political News
# Topic 4         Politican Stance
