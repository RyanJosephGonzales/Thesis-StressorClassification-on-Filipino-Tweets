# %%
import numpy as np
import pandas as pd
from time import sleep
import csv
import twint
import nest_asyncio
nest_asyncio.apply()

# %%
#Configuration
c = twint.Config()
c.Search = "oustduterte"
c.Lang = "tl"
c.Show_hashtags = True
c.Limit = 1000
c.Count = True
c.Pandas = True
#c.Store_csv = True


#Search
twint.run.Search(c)

df = twint.storage.panda.Tweets_df
# Out:
# 1440225262759600129 2021-09-21 16:03:55 +0800 <LimitlessniGojo> Nagutom lang ako, yun lang natutunan ko sa klase ni sir Vic. Magutom
# 1440224280009187328 2021-09-21 16:00:01 +0800 <kumendeng> Uy, gagi! 'Wag kang magpaniwala sa haka-hakang matagumpay ang Green Revolution sa panahong Marcos—mas lalong nalugmok sa kahirapan ang mga Pilipino. Lumaganap ang malnutrisyon sa kabataan at bumagsak ang kita ng mga mamamayan.  #NeverAgain #NeverForget #OustDuterte NeverAgain,NeverForget,OustDuterte
# 1440223011244625927 2021-09-21 15:54:58 +0800 <imcheeseka> so bat nambobomba ng tubig?
# 1440222189706379265 2021-09-21 15:51:42 +0800 <timexed> Marcos, Duterte, walang pinag-iba! Parehong tuta, diktador, pasista!  #NeverAgain  #MarcosNotAHero  #DuterteWakasan #OustDuterte NeverAgain,MarcosNotAHero,DuterteWakasan,OustDuterte
# ...

# %%
df.shape
# Out:
# (738, 38)

# %%
text = df['tweet']
df2 = pd.DataFrame(text)
df2.head()
# Out:
#                                                tweet
# 0  Nagutom lang ako, yun lang natutunan ko sa kla...
# 1  Uy, gagi! 'Wag kang magpaniwala sa haka-hakang...
# 2                        so bat nambobomba ng tubig?
# 3  Marcos, Duterte, walang pinag-iba! Parehong tu...
# 4  Malinaw na malinaw na malinaw na pinapatagal l...

# %%
#Configuration
c1 = twint.Config()
c1.Search = "dilawan"
c1.Lang = "tl"
c1.Show_hashtags = True
c1.Limit = 1000
c1.Count = True
c1.Pandas = True
#c1.Store_csv = True


#Search
twint.run.Search(c1)

df3 = twint.storage.panda.Tweets_df
# Out:
# 1440225567144480776 2021-09-21 16:05:07 +0800 <cheerishthelove> ang narrative po na "hindi ako dds, hindi rin dilawan" ay applicable lang sa mga taong pinaglalaban padin ang bayan at ang karapatang pantao. Hindi sa mga taong ginagawang excuse ang "neutrality" para sa kanilang polical apathy at mga privileged cries. good afternoon.
# 1440225529668378630 2021-09-21 16:04:59 +0800 <HannahD62475399> Never Forget but Never to Dilawan this 2022
# 1440225345936916487 2021-09-21 16:04:15 +0800 <Debonai89539265> @quency_martinaC @inquirerdotnet UNYA AHA LAGI ANG 153 B NGA GITANG AN LANG SA INYONG DILAWAN SENATORS NAWALA NALANG NALANG SI PNOY NGANGA DYAPON WLAY INVESTIGATION TAPOS DZAI WALA KA KABALO SA DAP CURROPTION SA IMONG PNOY.
# 1440225248616464389 2021-09-21 16:03:52 +0800 <justbutterfly06> @robertmarion Never again sa dilawan😂💛💛
# 1440224967619055619 2021-09-21 16:02:45 +0800 <Dilawar54428398> ProShow Gold 9.0.3797 Crack + Activation Code [ Latest 2021]  https://t.co/PAklK98GpM
# ...

# %%
df3.shape
# Out:
# (1007, 38)

# %%
text = df3['tweet']
df4 = pd.DataFrame(text)
df4.head()
# Out:
#                                                tweet
# 0  ang narrative po na "hindi ako dds, hindi rin ...
# 1        Never Forget but Never to Dilawan this 2022
# 2  @quency_martinaC @inquirerdotnet UNYA AHA LAGI...
# 3            @robertmarion Never again sa dilawan😂💛💛
# 4  ProShow Gold 9.0.3797 Crack + Activation Code ...

# %%
df13 = df2.append(df4)
df13
# Out:
#                                                   tweet
# 0     Nagutom lang ako, yun lang natutunan ko sa kla...
# 1     Uy, gagi! 'Wag kang magpaniwala sa haka-hakang...
# 2                           so bat nambobomba ng tubig?
# 3     Marcos, Duterte, walang pinag-iba! Parehong tu...
# 4     Malinaw na malinaw na malinaw na pinapatagal l...
# ...                                                 ...
# 1002  کتنے #یوتھئیے ہیں آپ سب۔ بھلا #طالبان #ڈیرن_سی...
# 1003                                        Exactly 💯❤️
# 1004  @isabelmerana @NBCNews Yung sinasabi mong magn...
# 1005      @iqraa_jan @SajidTuri_MNA insha'Allah will be
# 1006    #MartyrdomofBibiSakina  https://t.co/5CtjEZEkKC
#
# [1745 rows x 1 columns]

# %%
#Configuration
c3 = twint.Config()
c3.Search = "duterte"
c3.Lang = "tl"
c3.Show_hashtags = True
c3.Limit = 1000
c3.Count = True
c3.Pandas = True
#c3.Store_csv = True


#Search
twint.run.Search(c3)

df5 = twint.storage.panda.Tweets_df
# Out:
# 1440225601126748164 2021-09-21 16:05:16 +0800 <ampado_m> @blabla68129410 @seph_punzalan17 @inquirerdotnet Ok pero never parin ako sknya,panu maputol politikal dynasty,at magbayad utang na loob Yan ky duterte pag sya presidente,like abswelto s kaso
# 1440225565076705286 2021-09-21 16:05:07 +0800 <Manindigan> MARCOS-DUTERTE, WALANG PINAG-IBA, PAREHONG TUTA, PAHIRAP, KURAP, DIKTADOR, PASISTA!   (Left pic mula sa Diliman Review 70’s, at kanan 2018 laban sa price hike at ibp mga paskil sa waiting shed sa UP)   #NeverForget  #FightRevisionism #MarcosNotAHero  #OUSTDUTERTENOW  https://t.co/Rt0VViszNE NeverForget,FightRevisionism,MarcosNotAHero,OUSTDUTERTENOW
# 1440225554695790600 2021-09-21 16:05:04 +0800 <russellkuBW> House Speaker Lord Allan Velasco asks President Rodrigo Duterte to reconsider mandatory face shield policy, citing findings of epidemiology experts and its effect on the country's garbage problem. | @bworldph  https://t.co/Xu5MOUL1C7
# ...

# %%
df5.shape
# Out:
# (1000, 38)

# %%
text = df5['tweet']
df6 = pd.DataFrame(text)
df6.head()
# Out:
#                                                tweet
# 0  @blabla68129410 @seph_punzalan17 @inquirerdotn...
# 1  MARCOS-DUTERTE, WALANG PINAG-IBA, PAREHONG TUT...
# 2  House Speaker Lord Allan Velasco asks Presiden...
# 3  JUST IN: House Speaker Lord Allan Velasco asks...
# 4  READ: House Speaker Lord Allan Velasco asks Pr...

# %%
df14 = df13.append(df6)
df14
# Out:
#                                                  tweet
# 0    Nagutom lang ako, yun lang natutunan ko sa kla...
# 1    Uy, gagi! 'Wag kang magpaniwala sa haka-hakang...
# 2                          so bat nambobomba ng tubig?
# 3    Marcos, Duterte, walang pinag-iba! Parehong tu...
# 4    Malinaw na malinaw na malinaw na pinapatagal l...
# ..                                                 ...
# 995  President Rodrigo Duterte says the proposed bu...
# 996  DUTERTE, TUTA! DIKTADOR, PASISTA!   OPPOSE THE...
# 997  His quest to quell dissent has extended to the...
# 998  Eh kasi kumpleto sya now kay Duterte: library,...
# 999  President Rodrigo Duterte says the proposed bu...
#
# [2745 rows x 1 columns]

# %%
#Configuration
c4 = twint.Config()
c4.Search = "lenirobredo"
c4.Lang = "tl"
c4.Show_hashtags = True
c4.Limit = 1000
c4.Count = True
c4.Pandas = True
#c4.Store_csv = True


#Search
twint.run.Search(c4)

df7 = twint.storage.panda.Tweets_df
# Out:
# 1440225866571608067 2021-09-21 16:06:19 +0800 <IpAz842uL> Sorry @lenirobredo, but that statement won't make you a presidentiable.  #NeverForget #NeverAgainToMartialLaw #NeverAgaintoDilawan #LeniDORO #LeniRobredo NeverForget,NeverAgainToMartialLaw,NeverAgaintoDilawan,LeniDORO,LeniRobredo
# 1440225378245627910 2021-09-21 16:04:22 +0800 <nurse_erik> I will alaways remember @lenirobredo as Fake VP and the most incompetent person in Ph politics and I will NOT STOP telling this to my kids and the whole Ph.
# 1440224831572643841 2021-09-21 16:02:12 +0800 <adriandeleon02> @introvertingfur @maharshalal @PhilippineStar @lenirobredo Leni it really is a dark and gloomy Philippines if you become President. God Forbid. We want a better Philippines like what PDuterte is doing. We DONT NEED U.
# 1440224552135507971 2021-09-21 16:01:05 +0800 <pieatot> @Pepsicollagen @lenirobredo Bwahahaha. Recto Boy for the winner!
# ...

# %%
df7.shape
# Out:
# (1012, 38)

# %%
text = df7['tweet']
df8 = pd.DataFrame(text)
df8.head()
# Out:
#                                                tweet
# 0  Sorry @lenirobredo, but that statement won't m...
# 1  I will alaways remember @lenirobredo as Fake V...
# 2  @introvertingfur @maharshalal @PhilippineStar ...
# 3  @Pepsicollagen @lenirobredo Bwahahaha. Recto B...
# 4           @lenirobredo kelan po kayo tatakbo madam

# %%
df15 = df14.append(df8)
df15
# Out:
#                                                   tweet
# 0     Nagutom lang ako, yun lang natutunan ko sa kla...
# 1     Uy, gagi! 'Wag kang magpaniwala sa haka-hakang...
# 2                           so bat nambobomba ng tubig?
# 3     Marcos, Duterte, walang pinag-iba! Parehong tu...
# 4     Malinaw na malinaw na malinaw na pinapatagal l...
# ...                                                 ...
# 1007  @SyLicoNgaAko @lenirobredo Fake medals, fake d...
# 1008          VP @lenirobredo, pakigalaw po ang baso. 💛
# 1009  @SyLicoNgaAko @lenirobredo KBL ni macoy ito. Y...
# 1010  @joshravan @iMPACTPH2019 @PinoyAkoBlog @leniro...
# 1011  We need you Madam VP @lenirobredo #Leni2022 fo...
#
# [3757 rows x 1 columns]

# %%
#Configuration
c5 = twint.Config()
c5.Search = "diokno"
c5.Lang = "tl"
c5.Show_hashtags = True
c5.Limit = 1000
c5.Count = True
c5.Pandas = True
#c5.Store_csv = True


#Search
twint.run.Search(c5)

df9 = twint.storage.panda.Tweets_df
# Out:
# 1440225895290081281 2021-09-21 16:06:26 +0800 <goodboykevin_> Parang di ko makakasundo housemate ko 😩
# 1440225548270129160 2021-09-21 16:05:03 +0800 <ken_diokno> 🥺🤍
# 1440225530746314753 2021-09-21 16:04:59 +0800 <goodboykevin_> Magbenta na rin kaya ako briefs 😗 may bibili ba jan?
# 1440225199996104711 2021-09-21 16:03:40 +0800 <1Hello6789> @mistercorpuz ayain mo sila mervin tas chaps. Tagaytay na agadd HAHAHA
# 1440224488600178693 2021-09-21 16:00:50 +0800 <susantayas> ANO BA YANNNNN AWIT PAMBATO MO SI CHEL DIOKNO NA HUMAN RIGHTS ADVOCATE PERO VOTE BBM KA RIN NA ANG TATAY AY MAMATAY TAO??? NUBAYANNNN WHAT AN UTTER DISAPPOINTMENT?!?!? 😬😬😩😩 GEH BAHALA KA ENTITLED KA SA SARILI MONG CHOICES PERO PLS GET YOUR FACTS RIGHT😖
# 1440224023166681095 2021-09-21 15:58:59 +0800 <1Hello6789> @mistercorpuz de joke sa friday. Tagaytay na
# 1440223585889517574 2021-09-21 15:57:15 +0800 <ken_diokno> &lt;3
# ...

# %%
df9.shape
# Out:
# (1002, 38)

# %%
text = df9['tweet']
df10 = pd.DataFrame(text)
df10.head()
# Out:
#                                                tweet
# 0            Parang di ko makakasundo housemate ko 😩
# 1                                                 🥺🤍
# 2  Magbenta na rin kaya ako briefs 😗 may bibili b...
# 3  @mistercorpuz ayain mo sila mervin tas chaps. ...
# 4  ANO BA YANNNNN AWIT PAMBATO MO SI CHEL DIOKNO ...

# %%
df16 = df15.append(df10)
df16
# Out:
#                                                   tweet
# 0     Nagutom lang ako, yun lang natutunan ko sa kla...
# 1     Uy, gagi! 'Wag kang magpaniwala sa haka-hakang...
# 2                           so bat nambobomba ng tubig?
# 3     Marcos, Duterte, walang pinag-iba! Parehong tu...
# 4     Malinaw na malinaw na malinaw na pinapatagal l...
# ...                                                 ...
# 997                                                   💜
# 998   @kthnlwdw chel diokno be lyk  https://t.co/qvH...
# 999   my father changing the channel when he saw che...
# 1000          i diokno about u but i'm feeling 2022 !!!
# 1001  كل الشكر والتقدير لجميع العاملين في القطاع الص...
#
# [4759 rows x 1 columns]

# %%
#Configuration
c6 = twint.Config()
c6.Search = "yorme"
c6.Lang = "tl"
c6.Show_hashtags = True
c6.Limit = 500
c6.Count = True
c6.Pandas = True
#c6.Store_csv = True


#Search
twint.run.Search(c6)

df11 = twint.storage.panda.Tweets_df
# Out:
# 1440226022792646658 2021-09-21 16:06:56 +0800 <GeneFajardo2> @JanPons10 Baka si Yorme nag utos, teritoryo nya Yan ah.
# 1440221075405623308 2021-09-21 15:47:17 +0800 <kween_jin> potangina galing mo naman sumayaw yorme koe   https://t.co/hYsIqKSvaB
# 1440215776409964547 2021-09-21 15:26:13 +0800 <RishMiranda0620> @mikenavallo VP Leni for president, Sentri or Yorme for Vice President 💛💛💛
# 1440215068814163968 2021-09-21 15:23:24 +0800 <AJ_Ian_Cones> @KuyaErjann @ChescaPersia Mukhang magdedeclare si Yorme
# 1440214623026757641 2021-09-21 15:21:38 +0800 <paulbearr> Yung mga kapulisan mo, Yorme. 😠
# 1440205703038193681 2021-09-21 14:46:11 +0800 <eyjeypostrado> konti na lang complete na!!
# 1440202459079606276 2021-09-21 14:33:18 +0800 <KienzleDizonCee> Alam mo yorme labs naman kita pero sorry hindi kita boboto MUNA kasi kailangan ka pa ng maynila. Paano na ang 9 yr goal mo na sinabi mo sa the bottomline 2 yrs ago?
# ...

# %%
df11.shape
# Out:
# (500, 38)

# %%
text = df11['tweet']
df12 = pd.DataFrame(text)
df12.head()
# Out:
#                                                tweet
# 0  @JanPons10 Baka si Yorme nag utos, teritoryo n...
# 1  potangina galing mo naman sumayaw yorme koe   ...
# 2  @mikenavallo VP Leni for president, Sentri or ...
# 3  @KuyaErjann @ChescaPersia Mukhang magdedeclare...
# 4                    Yung mga kapulisan mo, Yorme. 😠

# %%
df17 = df16.append(df12)
df17
# Out:
#                                                  tweet
# 0    Nagutom lang ako, yun lang natutunan ko sa kla...
# 1    Uy, gagi! 'Wag kang magpaniwala sa haka-hakang...
# 2                          so bat nambobomba ng tubig?
# 3    Marcos, Duterte, walang pinag-iba! Parehong tu...
# 4    Malinaw na malinaw na malinaw na pinapatagal l...
# ..                                                 ...
# 495  @johnlloydalnzo @alohamhowenn @heyrooo1 gooodb...
# 496           pass na sa inuman tangina HAHAHAHAHAHAHA
# 497                       literal na huling inom ko na
# 498  A rare picture of Yorme Wendy na namimigay ng ...
# 499  Happy 13th Anniv my love @_IUofficial !!  ft. ...
#
# [5259 rows x 1 columns]

# %%
#removing dupes
df17 = df17.drop_duplicates('tweet',keep='first')
df17
# Out:
#                                                  tweet
# 0    Nagutom lang ako, yun lang natutunan ko sa kla...
# 1    Uy, gagi! 'Wag kang magpaniwala sa haka-hakang...
# 2                          so bat nambobomba ng tubig?
# 3    Marcos, Duterte, walang pinag-iba! Parehong tu...
# 4    Malinaw na malinaw na malinaw na pinapatagal l...
# ..                                                 ...
# 495  @johnlloydalnzo @alohamhowenn @heyrooo1 gooodb...
# 496           pass na sa inuman tangina HAHAHAHAHAHAHA
# 497                       literal na huling inom ko na
# 498  A rare picture of Yorme Wendy na namimigay ng ...
# 499  Happy 13th Anniv my love @_IUofficial !!  ft. ...
#
# [5161 rows x 1 columns]

# %%
#saving to csv
df17.to_csv("tagalog.csv", encoding = 'utf-8', index = False)
